# %%
from game_strategies import bonus_play_strategy
from game_setup import Stack
import numpy as np

stacks = [
    Stack.from_array(np.array([99, 70])),   # decreasing_1
    Stack.from_array(np.array([99, 63])),   # decreasing_2
    Stack.from_array(np.array([1, 49])),   # increasing_1
    Stack.from_array(np.array([1, 29]))    # increasing_2
    ]

a, b = bonus_play_strategy(
    player=np.array([66, 22, 68, 90, 87]),
    stacks=stacks,
    remaining_deck=np.arange(2, 99),
    bonus_play_threshold=5
    )

print(a)
for s in b:
    print(s)
# Out:
# [66 22]
# ...
